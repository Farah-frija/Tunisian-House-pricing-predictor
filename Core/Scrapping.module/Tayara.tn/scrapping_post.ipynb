# %% [markdown]
# Scrapping des données pour chaque post et concatenation des colonnes

# %%
import scrapping_post as scrapping_post_module
import os
import pandas as pd

# %%
file_path = r"clean_rawData/clean_tayara_listings.csv"

if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print("File loaded, shape:", df.shape)
else:
    print("File not found at:", os.path.abspath(file_path))
# Out:
# File loaded, shape: (2144, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'titre', 'categorie', 'gouvernorat', 'neuf',
#        'source'],
#       dtype='object')

# %%
df_final = scrapping_post_module.enrich_dataframe_simple(df, url_column='url', delay=1)
# Out:
# Scraping 2144 URLs...
#   [1/2144] Scraping https://www.tayara.tn/item/maisons-et-villas/ben-arous/hammam-lif/hammamlif-chaabia-villa-400-m-vendre/693aba448914daae5199a829/
#   [2/2144] Scraping https://www.tayara.tn/item/maisons-et-villas/ben-arous/el-mourouj-6/a-vendre-villa-individuelle/69273d4a265523b710ebcdac/
#   [3/2144] Scraping https://www.tayara.tn/item/maisons-et-villas/tunis/tunis/villa-dexception-haut-standing-menzel-abderahmen/691704d8265523b710e48d74/
#   [4/2144] Scraping https://www.tayara.tn/item/appartements/ben-arous/medina-jedida/appartement-s2-el-mdina-jadida/693990a6cd04d08be748b829/
#   [5/2144] Scraping https://www.tayara.tn/item/appartements/tunis/ain-zaghouan-nord/appartement-ainzaghouansud/693ab7278914daae5199a66a/
#   💾 Sauvegarde dans: posts.csv (5 URLs traitées)
#   [6/2144] Scraping https://www.tayara.tn/item/appartements/monastir/monastir/a-vendre-appartement-s2-monastir-c1/693ab70e8914daae5199a65a/
# ...
